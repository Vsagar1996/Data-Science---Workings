# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# # Merging and Concatenating Dataframes

# %%
# dataset 1

df_movies = pd.read_csv("IMDb movies.csv",low_memory=False).sort_values(by="imdb_title_id")
df_movies = df_movies[["imdb_title_id","title","year","genre","country"]]
df_movies
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country
# 0                        Romance               USA
# 1        Biography, Crime, Drama         Australia
# 2                          Drama  Germany, Denmark
# 3                 Drama, History               USA
# 4      Adventure, Drama, Fantasy             Italy
# ...                          ...               ...
# 85850                     Comedy   France, Belgium
# 85851              Comedy, Drama       Netherlands
# 85852                      Drama             India
# 85853              Drama, Family            Turkey
# 85854                      Drama             Spain
#
# [85855 rows x 5 columns]

# %%
# dataset 2

df_ratings = pd.read_csv("IMDb ratings.csv").sort_values(by="imdb_title_id")
df_ratings = df_ratings[["imdb_title_id","total_votes","mean_vote"]]
df_ratings
# Out:
#       imdb_title_id  total_votes  mean_vote
# 0         tt0000009          154        5.9
# 1         tt0000574          589        6.3
# 2         tt0001892          188        6.0
# 3         tt0002101          446        5.3
# 4         tt0002130         2237        6.9
# ...             ...          ...        ...
# 85850     tt9908390          398        5.5
# 85851     tt9911196          724        7.9
# 85852     tt9911774          265        7.8
# 85853     tt9914286          194        9.4
# 85854     tt9914942          102        6.8
#
# [85855 rows x 3 columns]

# %%
# sample dataset 1

df_movies_sample = df_movies[df_movies.index.isin([0,2,4,6,8])]
df_movies_sample
# Out:
#   imdb_title_id                  title  year                      genre  \
# 0     tt0000009             Miss Jerry  1894                    Romance
# 2     tt0001892         Den sorte drøm  1911                      Drama
# 4     tt0002130              L'Inferno  1911  Adventure, Drama, Fantasy
# 6     tt0002423         Madame DuBarry  1919  Biography, Drama, Romance
# 8     tt0002452  Independenta Romaniei  1912               History, War
#
#             country
# 0               USA
# 2  Germany, Denmark
# 4             Italy
# 6           Germany
# 8           Romania

# %%
# sample dataset 2

df_ratings_sample = df_ratings[df_ratings.index.isin([0,1,2,3,4,5])]
df_ratings_sample
# Out:
#   imdb_title_id  total_votes  mean_vote
# 0     tt0000009          154        5.9
# 1     tt0000574          589        6.3
# 2     tt0001892          188        6.0
# 3     tt0002101          446        5.3
# 4     tt0002130         2237        6.9
# 5     tt0002199          484        5.8

# %% [markdown]
# # 1.  Concatenate - concat()

# %% [markdown]
# ### 1.1   Concatenate (vertically or along the row, axis=0)

# %%
df1=pd.DataFrame({"id":["A","B","C","D"],"age":[30,23,25,22],"Gender":["M","F","M","M"]})
df1
# Out:
#   id  age Gender
# 0  A   30      M
# 1  B   23      F
# 2  C   25      M
# 3  D   22      M

# %%
df2 = pd.DataFrame({"id":["E","F","G","A","B"],"age":[40,21,19,24,36],"Score":[85,70,96,100,90]})
df2
# Out:
#   id  age  Score
# 0  E   40     85
# 1  F   21     70
# 2  G   19     96
# 3  A   24    100
# 4  B   36     90

# %%
pd.concat([df1,df2],axis=0)  # by default axis=0 and outer join
# Out:
#   id  age Gender  Score
# 0  A   30      M    NaN
# 1  B   23      F    NaN
# 2  C   25      M    NaN
# 3  D   22      M    NaN
# 0  E   40    NaN   85.0
# 1  F   21    NaN   70.0
# 2  G   19    NaN   96.0
# 3  A   24    NaN  100.0
# 4  B   36    NaN   90.0

# %%
# avoid duplicate indexes

pd.concat([df1,df2],axis=0, ignore_index=True)
# Out:
#   id  age Gender  Score
# 0  A   30      M    NaN
# 1  B   23      F    NaN
# 2  C   25      M    NaN
# 3  D   22      M    NaN
# 4  E   40    NaN   85.0
# 5  F   21    NaN   70.0
# 6  G   19    NaN   96.0
# 7  A   24    NaN  100.0
# 8  B   36    NaN   90.0

# %%
pd.concat([df1.set_index("id"),df2.set_index("id")],axis=0)
# Out:
#     age Gender  Score
# id
# A    30      M    NaN
# B    23      F    NaN
# C    25      M    NaN
# D    22      M    NaN
# E    40    NaN   85.0
# F    21    NaN   70.0
# G    19    NaN   96.0
# A    24    NaN  100.0
# B    36    NaN   90.0

# %%
pd.concat([df1.set_index("id"),df2.set_index("id")],axis=0,ignore_index=True)
# Out:
#    age Gender  Score
# 0   30      M    NaN
# 1   23      F    NaN
# 2   25      M    NaN
# 3   22      M    NaN
# 4   40    NaN   85.0
# 5   21    NaN   70.0
# 6   19    NaN   96.0
# 7   24    NaN  100.0
# 8   36    NaN   90.0

# %%
pd.concat([df1,df2],axis=0,join="inner") # shows only non null values
# Out:
#   id  age
# 0  A   30
# 1  B   23
# 2  C   25
# 3  D   22
# 0  E   40
# 1  F   21
# 2  G   19
# 3  A   24
# 4  B   36

# %%
df3 = pd.DataFrame({"id":["A","A","B","C","D"],"age":[30,23,25,22,45],"Gender":["M","F","M","M","F"]})
df3
# Out:
#   id  age Gender
# 0  A   30      M
# 1  A   23      F
# 2  B   25      M
# 3  C   22      M
# 4  D   45      F

# %%
df4 = pd.DataFrame({"id":["E","F","G","A","B","B"],"age":[40,21,19,24,36,52],"Score":[85,70,96,100,90,75]})
df4
# Out:
#   id  age  Score
# 0  E   40     85
# 1  F   21     70
# 2  G   19     96
# 3  A   24    100
# 4  B   36     90
# 5  B   52     75

# %%
pd.concat([df3,df4], axis=0)
# Out:
#   id  age Gender  Score
# 0  A   30      M    NaN
# 1  A   23      F    NaN
# 2  B   25      M    NaN
# 3  C   22      M    NaN
# 4  D   45      F    NaN
# 0  E   40    NaN   85.0
# 1  F   21    NaN   70.0
# 2  G   19    NaN   96.0
# 3  A   24    NaN  100.0
# 4  B   36    NaN   90.0
# 5  B   52    NaN   75.0

# %%
pd.concat([df3.set_index("id"),df4.set_index("id")], axis=0)
# Out:
#     age Gender  Score
# id
# A    30      M    NaN
# A    23      F    NaN
# B    25      M    NaN
# C    22      M    NaN
# D    45      F    NaN
# E    40    NaN   85.0
# F    21    NaN   70.0
# G    19    NaN   96.0
# A    24    NaN  100.0
# B    36    NaN   90.0
# B    52    NaN   75.0

# %%
# concatenate vertically df_movies_sample and df_ratings_sample

pd.concat([df_movies_sample,df_ratings_sample],axis=0,ignore_index=True)
# Out:
#    imdb_title_id                  title  year                      genre  \
# 0      tt0000009             Miss Jerry  1894                    Romance
# 1      tt0001892         Den sorte drøm  1911                      Drama
# 2      tt0002130              L'Inferno  1911  Adventure, Drama, Fantasy
# 3      tt0002423         Madame DuBarry  1919  Biography, Drama, Romance
# 4      tt0002452  Independenta Romaniei  1912               History, War
# 5      tt0000009                    NaN   NaN                        NaN
# 6      tt0000574                    NaN   NaN                        NaN
# 7      tt0001892                    NaN   NaN                        NaN
# 8      tt0002101                    NaN   NaN                        NaN
# 9      tt0002130                    NaN   NaN                        NaN
# 10     tt0002199                    NaN   NaN                        NaN
#
#              country  total_votes  mean_vote
# 0                USA          NaN        NaN
# 1   Germany, Denmark          NaN        NaN
# 2              Italy          NaN        NaN
# 3            Germany          NaN        NaN
# 4            Romania          NaN        NaN
# 5                NaN        154.0        5.9
# 6                NaN        589.0        6.3
# 7                NaN        188.0        6.0
# 8                NaN        446.0        5.3
# 9                NaN       2237.0        6.9
# 10               NaN        484.0        5.8

# %%
# setting common index and concatenate vertically df_movies_sample and df_ratings_sample

pd.concat([df_movies_sample.set_index("imdb_title_id"),df_ratings_sample.set_index("imdb_title_id")],axis=0)
# Out:
#                                title  year                      genre  \
# imdb_title_id
# tt0000009                 Miss Jerry  1894                    Romance
# tt0001892             Den sorte drøm  1911                      Drama
# tt0002130                  L'Inferno  1911  Adventure, Drama, Fantasy
# tt0002423             Madame DuBarry  1919  Biography, Drama, Romance
# tt0002452      Independenta Romaniei  1912               History, War
# tt0000009                        NaN   NaN                        NaN
# tt0000574                        NaN   NaN                        NaN
# tt0001892                        NaN   NaN                        NaN
# tt0002101                        NaN   NaN                        NaN
# tt0002130                        NaN   NaN                        NaN
# tt0002199                        NaN   NaN                        NaN
#
#                         country  total_votes  mean_vote
# imdb_title_id
# tt0000009                   USA          NaN        NaN
# tt0001892      Germany, Denmark          NaN        NaN
# tt0002130                 Italy          NaN        NaN
# tt0002423               Germany          NaN        NaN
# tt0002452               Romania          NaN        NaN
# tt0000009                   NaN        154.0        5.9
# tt0000574                   NaN        589.0        6.3
# tt0001892                   NaN        188.0        6.0
# tt0002101                   NaN        446.0        5.3
# tt0002130                   NaN       2237.0        6.9
# tt0002199                   NaN        484.0        5.8

# %% [markdown]
# # 1.2  Concatenate (horizontally or along the column, axis=1)

# %%
pd.concat([df1,df2],axis=1)
# Out:
#     id   age Gender id  age  Score
# 0    A  30.0      M  E   40     85
# 1    B  23.0      F  F   21     70
# 2    C  25.0      M  G   19     96
# 3    D  22.0      M  A   24    100
# 4  NaN   NaN    NaN  B   36     90

# %% [markdown]
# Indexes (important!)
#
# df1 index → [0, 1, 2, 3]
#
# df2 index → [0, 1, 2, 3, 4]
#
# ###### Key rules applied:
#
# - Concatenate columns side-by-side
#
# - Align rows by index, NOT by id
#
# - Uses outer join on index (default)
#
# - Missing values → NaN
#
# ###### Conclusion:
#
# - The id column is not used to match rows
#
# - Pandas only matches by index position
#
# - So "A" in df1 is not matched with "A" in df2

# %%
pd.concat([df1,df2],axis=1, join="inner")
# pd.concat([df1,df2],axis=1, join="outer") 'outer' by default
# Out:
#   id  age Gender id  age  Score
# 0  A   30      M  E   40     85
# 1  B   23      F  F   21     70
# 2  C   25      M  G   19     96
# 3  D   22      M  A   24    100

# %%
# indexing the dataframes and then concating

pd.concat([df1.set_index("id"),df2.set_index("id")],axis=1)
# Out:
#      age Gender   age  Score
# id
# A   30.0      M  24.0  100.0
# B   23.0      F  36.0   90.0
# C   25.0      M   NaN    NaN
# D   22.0      M   NaN    NaN
# E    NaN    NaN  40.0   85.0
# F    NaN    NaN  21.0   70.0
# G    NaN    NaN  19.0   96.0

# %%
pd.concat([df1.set_index("id"),df2.set_index("id")],axis=1, join="inner")
# Out:
#     age Gender  age  Score
# id
# A    30      M   24    100
# B    23      F   36     90

# %%
pd.concat([df3,df4],axis=1)
# Out:
#     id   age Gender id  age  Score
# 0    A  30.0      M  E   40     85
# 1    A  23.0      F  F   21     70
# 2    B  25.0      M  G   19     96
# 3    C  22.0      M  A   24    100
# 4    D  45.0      F  B   36     90
# 5  NaN   NaN    NaN  B   52     75

# %%
# pd.concat([df3.set_index("id"),df4.set_index("id")],axis=1)

# shows error as there is duplicate index

# %% [markdown]
# #### What pandas does:
#
# - Concatenates columns
#
# - Aligns rows by index (id)
#
# - Uses outer join on index
#
# - Does NOT create combinations for duplicate keys
#
# #### Why this happens:
#
# - concat(axis=1) with duplicate indexes:
#
# - Pandas aligns row-by-row, not many-to-many
#
# - It matches only the first occurrence per index
#
# - Extra duplicate rows remain unmatched → NaN
#
# - concat cannot do relational joins with duplicates
#
# #### What you probably expected:
#
# - If you expected all combinations for A and B (many-to-many join), you must use merge():
#
# #### Rule to remember:
#
# - If indexes are unique → concat(axis=1) is OK
# If duplicates exist → use merge()

# %%
# concatenate horizontally df_movies_sample and df_ratings_sample

pd.concat([df_movies_sample,df_ratings_sample],axis=1)
# Out:
#   imdb_title_id                  title  year                      genre  \
# 0     tt0000009             Miss Jerry  1894                    Romance
# 2     tt0001892         Den sorte drøm  1911                      Drama
# 4     tt0002130              L'Inferno  1911  Adventure, Drama, Fantasy
# 6     tt0002423         Madame DuBarry  1919  Biography, Drama, Romance
# 8     tt0002452  Independenta Romaniei  1912               History, War
# 1           NaN                    NaN   NaN                        NaN
# 3           NaN                    NaN   NaN                        NaN
# 5           NaN                    NaN   NaN                        NaN
#
#             country imdb_title_id  total_votes  mean_vote
# 0               USA     tt0000009        154.0        5.9
# 2  Germany, Denmark     tt0001892        188.0        6.0
# 4             Italy     tt0002130       2237.0        6.9
# 6           Germany           NaN          NaN        NaN
# 8           Romania           NaN          NaN        NaN
# 1               NaN     tt0000574        589.0        6.3
# 3               NaN     tt0002101        446.0        5.3
# 5               NaN     tt0002199        484.0        5.8

# %%
# concatenate horizontally df_movies_sample and df_ratings_sample

pd.concat([df_movies_sample.set_index("imdb_title_id"),df_ratings_sample.set_index("imdb_title_id")],axis=1)
# Out:
#                                title  year                      genre  \
# imdb_title_id
# tt0000009                 Miss Jerry  1894                    Romance
# tt0001892             Den sorte drøm  1911                      Drama
# tt0002130                  L'Inferno  1911  Adventure, Drama, Fantasy
# tt0002423             Madame DuBarry  1919  Biography, Drama, Romance
# tt0002452      Independenta Romaniei  1912               History, War
# tt0000574                        NaN   NaN                        NaN
# tt0002101                        NaN   NaN                        NaN
# tt0002199                        NaN   NaN                        NaN
#
#                         country  total_votes  mean_vote
# imdb_title_id
# tt0000009                   USA        154.0        5.9
# tt0001892      Germany, Denmark        188.0        6.0
# tt0002130                 Italy       2237.0        6.9
# tt0002423               Germany          NaN        NaN
# tt0002452               Romania          NaN        NaN
# tt0000574                   NaN        589.0        6.3
# tt0002101                   NaN        446.0        5.3
# tt0002199                   NaN        484.0        5.8

# %% [markdown]
# # 2)  Joins

# %% [markdown]
# ## 2.1)  Inner Join

# %% [markdown]
# Return common matching data of two dataframes - intersection of two dataframes

# %%
df1=pd.DataFrame({"id":["A","B","C","D"],"age":[30,23,25,22]})
df1
# Out:
#   id  age
# 0  A   30
# 1  B   23
# 2  C   25
# 3  D   22

# %%
df2=pd.DataFrame({"id":["C","D","E","F"],"job":["Doctor","Statistician","Accountant","Developer"],"salary":[30000,20000,10000,40000]})
df2
# Out:
#   id           job  salary
# 0  C        Doctor   30000
# 1  D  Statistician   20000
# 2  E    Accountant   10000
# 3  F     Developer   40000

# %%
df1.merge(df2,on="id",how="inner")  # default value of 'keep' is 'inner'
# Out:
#   id  age           job  salary
# 0  C   25        Doctor   30000
# 1  D   22  Statistician   20000

# %%
df2.merge(df1,on="id",how="inner")
# Out:
#   id           job  salary  age
# 0  C        Doctor   30000   25
# 1  D  Statistician   20000   22

# %%
# Exercise

# merge df_movies_sample and df_ratings_sample based on "imdb_title_id"

df_movies_sample.merge(df_ratings_sample,on="imdb_title_id",how="inner")

# pd.merge(df_movies,df_ratings, on="imdb_title_id",how="inner") - another way
# Out:
#   imdb_title_id           title  year                      genre  \
# 0     tt0000009      Miss Jerry  1894                    Romance
# 1     tt0001892  Den sorte drøm  1911                      Drama
# 2     tt0002130       L'Inferno  1911  Adventure, Drama, Fantasy
#
#             country  total_votes  mean_vote
# 0               USA          154        5.9
# 1  Germany, Denmark          188        6.0
# 2             Italy         2237        6.9

# %% [markdown]
# ## 2.2) Outer join (Full join)

# %% [markdown]
# Returns common and full data of both dataframes - union of two databases

# %%
df1=pd.DataFrame({"id":["A","B","C","D"],"age":[30,23,25,22]})
df1
# Out:
#   id  age
# 0  A   30
# 1  B   23
# 2  C   25
# 3  D   22

# %%
df2=pd.DataFrame({"id":["C","D","E","F"],"job":["Doctor","Statistician","Accountant","Developer"],"salary":[30000,20000,10000,40000]})
df2
# Out:
#   id           job  salary
# 0  C        Doctor   30000
# 1  D  Statistician   20000
# 2  E    Accountant   10000
# 3  F     Developer   40000

# %%
df1.merge(df2,on="id",how="outer")
# Out:
#   id   age           job   salary
# 0  A  30.0           NaN      NaN
# 1  B  23.0           NaN      NaN
# 2  C  25.0        Doctor  30000.0
# 3  D  22.0  Statistician  20000.0
# 4  E   NaN    Accountant  10000.0
# 5  F   NaN     Developer  40000.0

# %%
df2.merge(df1,on="id",how="outer")
# Out:
#   id           job   salary   age
# 0  A           NaN      NaN  30.0
# 1  B           NaN      NaN  23.0
# 2  C        Doctor  30000.0  25.0
# 3  D  Statistician  20000.0  22.0
# 4  E    Accountant  10000.0   NaN
# 5  F     Developer  40000.0   NaN

# %%
# Exercise

# merge df_movies_sample and df_ratings_sample based on "imdb_title_id"

df_movies_sample.merge(df_ratings_sample,on="imdb_title_id",how="outer")

# pd.merge(df_movies_sample,df_ratings_sample, on="imdb_title_id",how="outer")   # another way
# Out:
#   imdb_title_id                  title  year                      genre  \
# 0     tt0000009             Miss Jerry  1894                    Romance
# 1     tt0000574                    NaN   NaN                        NaN
# 2     tt0001892         Den sorte drøm  1911                      Drama
# 3     tt0002101                    NaN   NaN                        NaN
# 4     tt0002130              L'Inferno  1911  Adventure, Drama, Fantasy
# 5     tt0002199                    NaN   NaN                        NaN
# 6     tt0002423         Madame DuBarry  1919  Biography, Drama, Romance
# 7     tt0002452  Independenta Romaniei  1912               History, War
#
#             country  total_votes  mean_vote
# 0               USA        154.0        5.9
# 1               NaN        589.0        6.3
# 2  Germany, Denmark        188.0        6.0
# 3               NaN        446.0        5.3
# 4             Italy       2237.0        6.9
# 5               NaN        484.0        5.8
# 6           Germany          NaN        NaN
# 7           Romania          NaN        NaN

# %% [markdown]
# ### 2.2.1) Exclusive full join

# %% [markdown]
# returns all data excluding the common part

# %%
df_movies_sample.merge(df_ratings_sample,on="imdb_title_id",how="outer",indicator=True)  # a new column _merge is formed
# Out:
#   imdb_title_id                  title  year                      genre  \
# 0     tt0000009             Miss Jerry  1894                    Romance
# 1     tt0000574                    NaN   NaN                        NaN
# 2     tt0001892         Den sorte drøm  1911                      Drama
# 3     tt0002101                    NaN   NaN                        NaN
# 4     tt0002130              L'Inferno  1911  Adventure, Drama, Fantasy
# 5     tt0002199                    NaN   NaN                        NaN
# 6     tt0002423         Madame DuBarry  1919  Biography, Drama, Romance
# 7     tt0002452  Independenta Romaniei  1912               History, War
#
#             country  total_votes  mean_vote      _merge
# 0               USA        154.0        5.9        both
# 1               NaN        589.0        6.3  right_only
# 2  Germany, Denmark        188.0        6.0        both
# 3               NaN        446.0        5.3  right_only
# 4             Italy       2237.0        6.9        both
# 5               NaN        484.0        5.8  right_only
# 6           Germany          NaN        NaN   left_only
# 7           Romania          NaN        NaN   left_only

# %%
df_movies_sample.merge(df_ratings_sample,on="imdb_title_id",how="outer",indicator=True).query("_merge != 'both'")

# df_movies_sample.merge(df_ratings_sample,on="imdb_title_id",how="outer",indicator=True).query("_merge == 'left_only' or _merge == 'right_only'")
# Out:
#   imdb_title_id                  title  year                      genre  \
# 1     tt0000574                    NaN   NaN                        NaN
# 3     tt0002101                    NaN   NaN                        NaN
# 5     tt0002199                    NaN   NaN                        NaN
# 6     tt0002423         Madame DuBarry  1919  Biography, Drama, Romance
# 7     tt0002452  Independenta Romaniei  1912               History, War
#
#    country  total_votes  mean_vote      _merge
# 1      NaN        589.0        6.3  right_only
# 3      NaN        446.0        5.3  right_only
# 5      NaN        484.0        5.8  right_only
# 6  Germany          NaN        NaN   left_only
# 7  Romania          NaN        NaN   left_only

# %% [markdown]
# ## 2.3) Left join

# %% [markdown]
# Return common data and data of the first dataframe

# %%
df1=pd.DataFrame({"id":["A","B","C","D"],"age":[30,23,25,22]})
df1
# Out:
#   id  age
# 0  A   30
# 1  B   23
# 2  C   25
# 3  D   22

# %%
df2=pd.DataFrame({"id":["C","D","E","F"],"job":["Doctor","Statistician","Accountant","Developer"],"salary":[30000,20000,10000,40000]})
df2
# Out:
#   id           job  salary
# 0  C        Doctor   30000
# 1  D  Statistician   20000
# 2  E    Accountant   10000
# 3  F     Developer   40000

# %%
df1.merge(df2,on="id",how="left")
# Out:
#   id  age           job   salary
# 0  A   30           NaN      NaN
# 1  B   23           NaN      NaN
# 2  C   25        Doctor  30000.0
# 3  D   22  Statistician  20000.0

# %%
df2.merge(df1,on="id",how="left")
# Out:
#   id           job  salary   age
# 0  C        Doctor   30000  25.0
# 1  D  Statistician   20000  22.0
# 2  E    Accountant   10000   NaN
# 3  F     Developer   40000   NaN

# %%
# Exercise

# merge df_movies_sample and df_ratings_sample based on "imdb_title_id"

df_movies_sample.merge(df_ratings_sample,on="imdb_title_id",how="left")

# pd.merge(df_movies_sample,df_ratings_sample, on="imdb_title_id",how="left")   # another way
# Out:
#   imdb_title_id                  title  year                      genre  \
# 0     tt0000009             Miss Jerry  1894                    Romance
# 1     tt0001892         Den sorte drøm  1911                      Drama
# 2     tt0002130              L'Inferno  1911  Adventure, Drama, Fantasy
# 3     tt0002423         Madame DuBarry  1919  Biography, Drama, Romance
# 4     tt0002452  Independenta Romaniei  1912               History, War
#
#             country  total_votes  mean_vote
# 0               USA        154.0        5.9
# 1  Germany, Denmark        188.0        6.0
# 2             Italy       2237.0        6.9
# 3           Germany          NaN        NaN
# 4           Romania          NaN        NaN

# %%
df_ratings_sample.merge(df_movies_sample,on="imdb_title_id",how="left")
# Out:
#   imdb_title_id  total_votes  mean_vote           title  year  \
# 0     tt0000009          154        5.9      Miss Jerry  1894
# 1     tt0000574          589        6.3             NaN   NaN
# 2     tt0001892          188        6.0  Den sorte drøm  1911
# 3     tt0002101          446        5.3             NaN   NaN
# 4     tt0002130         2237        6.9       L'Inferno  1911
# 5     tt0002199          484        5.8             NaN   NaN
#
#                        genre           country
# 0                    Romance               USA
# 1                        NaN               NaN
# 2                      Drama  Germany, Denmark
# 3                        NaN               NaN
# 4  Adventure, Drama, Fantasy             Italy
# 5                        NaN               NaN

# %% [markdown]
# #### 2.3.1)  Exclusive left join

# %%
df_ratings_sample.merge(df_movies_sample,on="imdb_title_id",how="left",indicator=True)
# Out:
#   imdb_title_id  total_votes  mean_vote           title  year  \
# 0     tt0000009          154        5.9      Miss Jerry  1894
# 1     tt0000574          589        6.3             NaN   NaN
# 2     tt0001892          188        6.0  Den sorte drøm  1911
# 3     tt0002101          446        5.3             NaN   NaN
# 4     tt0002130         2237        6.9       L'Inferno  1911
# 5     tt0002199          484        5.8             NaN   NaN
#
#                        genre           country     _merge
# 0                    Romance               USA       both
# 1                        NaN               NaN  left_only
# 2                      Drama  Germany, Denmark       both
# 3                        NaN               NaN  left_only
# 4  Adventure, Drama, Fantasy             Italy       both
# 5                        NaN               NaN  left_only

# %%
df_ratings_sample.merge(df_movies_sample,on="imdb_title_id",how="left",indicator=True).query("_merge == 'left_only'")
# Out:
#   imdb_title_id  total_votes  mean_vote title year genre country     _merge
# 1     tt0000574          589        6.3   NaN  NaN   NaN     NaN  left_only
# 3     tt0002101          446        5.3   NaN  NaN   NaN     NaN  left_only
# 5     tt0002199          484        5.8   NaN  NaN   NaN     NaN  left_only

# %% [markdown]
# ## 2.4) Right join

# %% [markdown]
# Return common data and data of the second dataframe

# %%
df1=pd.DataFrame({"id":["A","B","C","D"],"age":[30,23,25,22]})
df1
# Out:
#   id  age
# 0  A   30
# 1  B   23
# 2  C   25
# 3  D   22

# %%
df2=pd.DataFrame({"id":["C","D","E","F"],"job":["Doctor","Statistician","Accountant","Developer"],"salary":[30000,20000,10000,40000]})
df2
# Out:
#   id           job  salary
# 0  C        Doctor   30000
# 1  D  Statistician   20000
# 2  E    Accountant   10000
# 3  F     Developer   40000

# %%
df1.merge(df2,on="id",how="right")
# Out:
#   id   age           job  salary
# 0  C  25.0        Doctor   30000
# 1  D  22.0  Statistician   20000
# 2  E   NaN    Accountant   10000
# 3  F   NaN     Developer   40000

# %%
df2.merge(df1,on="id",how="right")
# Out:
#   id           job   salary  age
# 0  A           NaN      NaN   30
# 1  B           NaN      NaN   23
# 2  C        Doctor  30000.0   25
# 3  D  Statistician  20000.0   22

# %%
#Exercise

# merge df_movies_sample and df_ratings_sample based on "imdb_title_id"

df_movies_sample.merge(df_ratings_sample,on="imdb_title_id",how="right")

# pd.merge(df_movies_sample,df_ratings_sample, on="imdb_title_id",how="left")   # another way
# Out:
#   imdb_title_id           title  year                      genre  \
# 0     tt0000009      Miss Jerry  1894                    Romance
# 1     tt0000574             NaN   NaN                        NaN
# 2     tt0001892  Den sorte drøm  1911                      Drama
# 3     tt0002101             NaN   NaN                        NaN
# 4     tt0002130       L'Inferno  1911  Adventure, Drama, Fantasy
# 5     tt0002199             NaN   NaN                        NaN
#
#             country  total_votes  mean_vote
# 0               USA          154        5.9
# 1               NaN          589        6.3
# 2  Germany, Denmark          188        6.0
# 3               NaN          446        5.3
# 4             Italy         2237        6.9
# 5               NaN          484        5.8

# %%
df_ratings_sample.merge(df_movies_sample,on="imdb_title_id",how="right")
# Out:
#   imdb_title_id  total_votes  mean_vote                  title  year  \
# 0     tt0000009        154.0        5.9             Miss Jerry  1894
# 1     tt0001892        188.0        6.0         Den sorte drøm  1911
# 2     tt0002130       2237.0        6.9              L'Inferno  1911
# 3     tt0002423          NaN        NaN         Madame DuBarry  1919
# 4     tt0002452          NaN        NaN  Independenta Romaniei  1912
#
#                        genre           country
# 0                    Romance               USA
# 1                      Drama  Germany, Denmark
# 2  Adventure, Drama, Fantasy             Italy
# 3  Biography, Drama, Romance           Germany
# 4               History, War           Romania

# %% [markdown]
# ### 2.4.1) Exclusive right join

# %%
df_movies_sample.merge(df_ratings_sample,on="imdb_title_id",how="right",indicator=True)
# Out:
#   imdb_title_id           title  year                      genre  \
# 0     tt0000009      Miss Jerry  1894                    Romance
# 1     tt0000574             NaN   NaN                        NaN
# 2     tt0001892  Den sorte drøm  1911                      Drama
# 3     tt0002101             NaN   NaN                        NaN
# 4     tt0002130       L'Inferno  1911  Adventure, Drama, Fantasy
# 5     tt0002199             NaN   NaN                        NaN
#
#             country  total_votes  mean_vote      _merge
# 0               USA          154        5.9        both
# 1               NaN          589        6.3  right_only
# 2  Germany, Denmark          188        6.0        both
# 3               NaN          446        5.3  right_only
# 4             Italy         2237        6.9        both
# 5               NaN          484        5.8  right_only

# %%
#df_movies.merge(df_ratings,on="imdb_title_id",how="right",indicator=True).query("_merge == 'right_only'")

df_movies_sample.merge(df_ratings_sample,on="imdb_title_id",how="outer",indicator=True).query("_merge == 'right_only'") # can also use this
# Out:
#   imdb_title_id title year genre country  total_votes  mean_vote      _merge
# 1     tt0000574   NaN  NaN   NaN     NaN        589.0        6.3  right_only
# 3     tt0002101   NaN  NaN   NaN     NaN        446.0        5.3  right_only
# 5     tt0002199   NaN  NaN   NaN     NaN        484.0        5.8  right_only

# %%
# Exercise - make a copy of the dataframe and set the first 5 values of 'imdb_title_id' as 'tt1234567890'

df_movies1 = df_movies.copy()

for index in df_movies1.index:
    if index < 5:
        df_movies1.loc[index,"imdb_title_id"] = "tt1234567890"
df_movies1
# Out:
#       imdb_title_id                           title  year  \
# 0      tt1234567890                      Miss Jerry  1894
# 1      tt1234567890     The Story of the Kelly Gang  1906
# 2      tt1234567890                  Den sorte drøm  1911
# 3      tt1234567890                       Cleopatra  1912
# 4      tt1234567890                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country
# 0                        Romance               USA
# 1        Biography, Crime, Drama         Australia
# 2                          Drama  Germany, Denmark
# 3                 Drama, History               USA
# 4      Adventure, Drama, Fantasy             Italy
# ...                          ...               ...
# 85850                     Comedy   France, Belgium
# 85851              Comedy, Drama       Netherlands
# 85852                      Drama             India
# 85853              Drama, Family            Turkey
# 85854                      Drama             Spain
#
# [85855 rows x 5 columns]

# %% [markdown]
# #### Merging dataframes on different column names

# %%
df1=pd.DataFrame({"id1":["A","B","C","D"],"age":[30,23,25,22]})
df1
# Out:
#   id1  age
# 0   A   30
# 1   B   23
# 2   C   25
# 3   D   22

# %%
df2=pd.DataFrame({"id2":["C","D","E","F"],"job":["Doctor","Statistician","Accountant","Developer"],"salary":[30000,20000,10000,40000]})
df2
# Out:
#   id2           job  salary
# 0   C        Doctor   30000
# 1   D  Statistician   20000
# 2   E    Accountant   10000
# 3   F     Developer   40000

# %%
df1.merge(df2, left_on= "id1", right_on = "id2", how = "inner")

# the same can done for outer/left/right/exclusive joins
# Out:
#   id1  age id2           job  salary
# 0   C   25   C        Doctor   30000
# 1   D   22   D  Statistician   20000

# %%
pd.merge(df1, df2, left_on= "id1", right_on = "id2", how = "inner")

# the same can done for outer/left/right/exclusive joins
# Out:
#   id1  age id2           job  salary
# 0   C   25   C        Doctor   30000
# 1   D   22   D  Statistician   20000

# %% [markdown]
# ## join() method

# %%
df5=pd.DataFrame({"id1":["A","B","C","D"],"age":[30,23,25,22]}).set_index("id1")
df5
# Out:
#      age
# id1
# A     30
# B     23
# C     25
# D     22

# %%
df6=pd.DataFrame({"id2":["C","D","E","F"],"job":["Doctor","Statistician","Accountant","Developer"],"salary":[30000,20000,10000,40000]}).set_index("id2")
df6
# Out:
#               job  salary
# id2
# C          Doctor   30000
# D    Statistician   20000
# E      Accountant   10000
# F       Developer   40000

# %%
df5.join(df6, how = "inner")
# Out:
#    age           job  salary
# C   25        Doctor   30000
# D   22  Statistician   20000

# %%
# error will occur, as this syntax is not possible

# pd.join(df1, df2, how = "inner")
