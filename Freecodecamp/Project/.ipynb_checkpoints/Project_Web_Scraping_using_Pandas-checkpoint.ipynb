# %% [markdown]
# # Data Analysis of Football Match Performance Using Web-Scraped Data

# %% [markdown]
# ## Introduction
#
# This project analyzes football match data collected through web scraping.
# The dataset includes match results, team performance metrics, and
# disciplinary statistics across multiple seasons. The goal of this analysis
# is to explore patterns in match outcomes, team performance, and home
# advantage using exploratory data analysis techniques.

# %% [markdown]
# # Project Objectives
#
# The main objectives of this project are:
#
# - To collect real-world football match data through web scraping from an online football statistics source.
# - To clean and preprocess the scraped dataset by handling missing values, inconsistent formats, and redundant features.
# - To perform exploratory data analysis (EDA) to understand goal patterns, match outcomes, and home vs away performance.
# - To analyze team performance metrics such as goals scored, shots, fouls, and disciplinary actions.
# - To examine the relationship between match statistics and final match results.
# - To identify key insights and trends that influence football match outcomes using statistical techniques and visualizations.

# %%
# loading basic packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Web Scraping - Read CSV files from multiple URLs from the website

# %% [markdown]
# Target Website: https://www.football-data.co.uk/englandm.php

# %%
# Reading one CSV file from the website

DF2526= pd.read_csv("https://www.football-data.co.uk/mmz4281/2526/E0.csv")
DF2526
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  15/08/2025  20:00      Liverpool  Bournemouth     4     2   H     1
# 1    E0  16/08/2025  12:30    Aston Villa    Newcastle     0     0   D     0
# 2    E0  16/08/2025  15:00       Brighton       Fulham     1     1   D     0
# 3    E0  16/08/2025  15:00     Sunderland     West Ham     3     0   H     0
# 4    E0  16/08/2025  15:00      Tottenham      Burnley     3     0   H     1
# ..   ..         ...    ...            ...          ...   ...   ...  ..   ...
# 215  E0  17/01/2026  15:00      Tottenham     West Ham     1     2   A     0
# 216  E0  17/01/2026  17:30  Nott'm Forest      Arsenal     0     0   D     0
# 217  E0  18/01/2026  14:00         Wolves    Newcastle     0     0   D     0
# 218  E0  18/01/2026  16:30    Aston Villa      Everton     0     1   A     0
# 219  E0  19/01/2026  20:00       Brighton  Bournemouth     1     1   D     0
#
#      HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0       0  ...     2.03     1.78   2.07   1.85     2.03     1.88     1.94
# 1       0  ...     2.05     1.80   2.02   1.89     2.06     1.80     1.95
# 2       0  ...     1.83     2.03   1.93   2.00     1.84     2.03     1.80
# 3       0  ...     1.95     1.90   1.97   1.95     1.95     1.94     1.86
# 4       0  ...     1.98     1.88   1.99   1.93     1.98     1.91     1.88
# ..    ...  ...      ...      ...    ...    ...      ...      ...      ...
# 215     1  ...     1.85     2.00    NaN    NaN     1.95     2.00     1.80
# 216     0  ...     1.73     2.08    NaN    NaN     1.80     2.08     1.75
# 217     0  ...     1.95     1.90    NaN    NaN     1.95     1.92     1.89
# 218     0  ...     1.73     2.08    NaN    NaN     1.83     2.10     1.72
# 219     1  ...     1.95     1.90    NaN    NaN     1.96     1.90     1.89
#
#      AvgCAHA  BFECAHH  BFECAHA
# 0       1.76     2.14     1.86
# 1       1.74     2.14     1.86
# 2       1.96     1.91     2.08
# 3       1.78     2.02     1.97
# 4       1.83     2.07     1.92
# ..       ...      ...      ...
# 215     1.95     1.89     2.11
# 216     2.04     1.81     2.20
# 217     1.88     2.02     1.97
# 218     2.08     1.81     2.20
# 219     1.84     2.00     1.98
#
# [220 rows x 132 columns]

# %% [markdown]
# #### Link Structure
#
# "https://www.football-data.co.uk/mmz4281/" + "2425" + "/" + "E0/E1/E2/E3/EC" + ".csv"
#
#
# Link: root + season + league
#
# https://www.football-data.co.uk/mmz4281/2526/E0.csv
#
# https://www.football-data.co.uk/mmz4281/2526/E1.csv
#
# https://www.football-data.co.uk/mmz4281/2526/E2.csv
#
# https://www.football-data.co.uk/mmz4281/2526/E3.csv
#
# https://www.football-data.co.uk/mmz4281/2526/EC.csv
#
# https://www.football-data.co.uk/mmz4281/2425/E0.csv
#
# https://www.football-data.co.uk/mmz4281/2425/E1.csv
#
# https://www.football-data.co.uk/mmz4281/2425/E2.csv
#
# https://www.football-data.co.uk/mmz4281/2425/E3.csv
#
# https://www.football-data.co.uk/mmz4281/2425/EC.csv

# %%
# making a list of all leagues in 2025-26 season

leagues = ["E0","E1","E2","E3","EC"]
leagues_2526 = []
root = "https://www.football-data.co.uk/mmz4281/"
for league in leagues:
    df = pd.read_csv(root + "2526" + "/" + league + ".csv", encoding="unicode_escape")
    leagues_2526.append(df)

# %%
type(leagues_2526)
# Out:
# list

# %%
len(leagues_2526)
# Out:
# 5

# %%
# elements of the list will be a dataframes of league matches

#leagues_2526[0]
#leagues_2526[1]
#leagues_2526[2]
#leagues_2526[3]
leagues_2526[4]
# Out:
#     ï»¿Div        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0       EC  09/08/2025  15:00      Altrincham      Aldershot     3     2   H
# 1       EC  09/08/2025  15:00    Boreham Wood       Rochdale     0     2   A
# 2       EC  09/08/2025  15:00   Brackley Town      Eastleigh     1     0   H
# 3       EC  09/08/2025  15:00  Braintree Town        Halifax     3     0   H
# 4       EC  09/08/2025  15:00       Gateshead       Southend     0     3   A
# ..     ...         ...    ...             ...            ...   ...   ...  ..
# 318     EC  20/01/2026  19:45           Truro  Brackley Town     3     3   D
# 319     EC  21/01/2026  19:45        Carlisle           York     0     3   A
# 320     EC  21/01/2026  19:45    Forest Green     Altrincham     1     1   D
# 321     EC  21/01/2026  19:45         Halifax      Morecambe     1     0   H
# 322     EC  21/01/2026  19:45        Solihull       Rochdale     0     1   A
#
#      HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0       2     0  ...     1.90     1.90   1.92   1.93     1.90     1.90
# 1       0     0  ...     2.00     1.80   2.05   1.82     2.02     1.80
# 2       1     0  ...     2.00     1.80   2.14   1.72     2.03     1.80
# 3       2     0  ...     1.93     1.88   1.97   1.88     1.93     1.88
# 4       0     1  ...     1.83     1.98   1.67   2.19     1.83     2.04
# ..    ...   ...  ...      ...      ...    ...    ...      ...      ...
# 318     0     1  ...     1.75     2.05    NaN    NaN     1.75     2.05
# 319     0     1  ...     1.80     2.00    NaN    NaN     1.80     2.00
# 320     0     1  ...     2.00     1.80    NaN    NaN     2.00     1.80
# 321     1     0  ...     1.78     2.03    NaN    NaN     1.80     2.03
# 322     0     0  ...     1.93     1.88    NaN    NaN     1.93     1.88
#
#      AvgCAHH  AvgCAHA  BFECAHH  BFECAHA
# 0       1.86     1.84     2.00     1.99
# 1       1.96     1.75     2.06     1.89
# 2       1.96     1.75     2.06     1.84
# 3       1.88     1.82     1.97     1.98
# 4       1.75     1.96     1.84     2.12
# ..       ...      ...      ...      ...
# 318     1.69     2.04      NaN      NaN
# 319     1.77     1.94     1.87     2.06
# 320     1.95     1.75     2.12     1.81
# 321     1.76     1.94     1.93     2.05
# 322     1.89     1.81     2.00     1.97
#
# [323 rows x 124 columns]

# %%
for season in range(23,26):
    print(str(season) + str(season+1))
# Out:
# 2324
# 2425
# 2526

# %%
# Creating a list of all seasons and leagues

leagues = ["E0","E1","E2","E3","EC"]
AllSeasonLeagues = []
root = "https://www.football-data.co.uk/mmz4281/"
for league in leagues:
    for season in range(23,26):
        DF = pd.read_csv(root + str(season) + str(season+1) + "/" + league + ".csv")
        DF.insert(1,"Season",season)
        AllSeasonLeagues.append(DF)

# %%
type(AllSeasonLeagues)
# Out:
# list

# %%
# total (3 seasons into 5 leagues)

len(AllSeasonLeagues)
# Out:
# 15

# %%
# selecting a particular season and league

AllSeasonLeagues[14]
# Out:
#     Div  Season        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG  \
# 0    EC      25  09/08/2025  15:00      Altrincham      Aldershot     3     2
# 1    EC      25  09/08/2025  15:00    Boreham Wood       Rochdale     0     2
# 2    EC      25  09/08/2025  15:00   Brackley Town      Eastleigh     1     0
# 3    EC      25  09/08/2025  15:00  Braintree Town        Halifax     3     0
# 4    EC      25  09/08/2025  15:00       Gateshead       Southend     0     3
# ..   ..     ...         ...    ...             ...            ...   ...   ...
# 318  EC      25  20/01/2026  19:45           Truro  Brackley Town     3     3
# 319  EC      25  21/01/2026  19:45        Carlisle           York     0     3
# 320  EC      25  21/01/2026  19:45    Forest Green     Altrincham     1     1
# 321  EC      25  21/01/2026  19:45         Halifax      Morecambe     1     0
# 322  EC      25  21/01/2026  19:45        Solihull       Rochdale     0     1
#
#     FTR  HTHG  ...  B365CAHH B365CAHA PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0     H     2  ...      1.90     1.90  1.92   1.93     1.90     1.90     1.86
# 1     A     0  ...      2.00     1.80  2.05   1.82     2.02     1.80     1.96
# 2     H     1  ...      2.00     1.80  2.14   1.72     2.03     1.80     1.96
# 3     H     2  ...      1.93     1.88  1.97   1.88     1.93     1.88     1.88
# 4     A     0  ...      1.83     1.98  1.67   2.19     1.83     2.04     1.75
# ..   ..   ...  ...       ...      ...   ...    ...      ...      ...      ...
# 318   D     0  ...      1.75     2.05   NaN    NaN     1.75     2.05     1.69
# 319   A     0  ...      1.80     2.00   NaN    NaN     1.80     2.00     1.77
# 320   D     0  ...      2.00     1.80   NaN    NaN     2.00     1.80     1.95
# 321   H     1  ...      1.78     2.03   NaN    NaN     1.80     2.03     1.76
# 322   A     0  ...      1.93     1.88   NaN    NaN     1.93     1.88     1.89
#
#      AvgCAHA  BFECAHH  BFECAHA
# 0       1.84     2.00     1.99
# 1       1.75     2.06     1.89
# 2       1.75     2.06     1.84
# 3       1.82     1.97     1.98
# 4       1.96     1.84     2.12
# ..       ...      ...      ...
# 318     2.04      NaN      NaN
# 319     1.94     1.87     2.06
# 320     1.75     2.12     1.81
# 321     1.94     1.93     2.05
# 322     1.81     2.00     1.97
#
# [323 rows x 125 columns]

# %% [markdown]
# ### Combine all leagues and seasons in a single dataframe

# %%
# to combine all the dataframe to a single dataframe

DF_Concat = pd.concat(AllSeasonLeagues)
DF_Concat
# Out:
#     Div  Season        Date   Time      HomeTeam       AwayTeam  FTHG  FTAG  \
# 0    E0      23  11/08/2023  20:00       Burnley       Man City     0     3
# 1    E0      23  12/08/2023  12:30       Arsenal  Nott'm Forest     2     1
# 2    E0      23  12/08/2023  15:00   Bournemouth       West Ham     1     1
# 3    E0      23  12/08/2023  15:00      Brighton          Luton     4     1
# 4    E0      23  12/08/2023  15:00       Everton         Fulham     0     1
# ..   ..     ...         ...    ...           ...            ...   ...   ...
# 318  EC      25  20/01/2026  19:45         Truro  Brackley Town     3     3
# 319  EC      25  21/01/2026  19:45      Carlisle           York     0     3
# 320  EC      25  21/01/2026  19:45  Forest Green     Altrincham     1     1
# 321  EC      25  21/01/2026  19:45       Halifax      Morecambe     1     0
# 322  EC      25  21/01/2026  19:45      Solihull       Rochdale     0     1
#
#     FTR  HTHG  ...  BMGMCA  BVCH  BVCD  BVCA  CLCH  CLCD  CLCA  LBCH  LBCD  \
# 0     A     0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     H     2  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     D     0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     H     1  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     A     0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..   ..   ...  ...     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 318   D     0  ...    2.75  2.38  3.10  2.88   NaN   NaN   NaN   NaN   NaN
# 319   A     0  ...    2.20  2.75  3.60  2.20   NaN   NaN   NaN   NaN   NaN
# 320   D     0  ...    7.50  1.25  5.25  9.50   NaN   NaN   NaN   NaN   NaN
# 321   H     1  ...    3.45  1.80  3.80  3.70   NaN   NaN   NaN   NaN   NaN
# 322   A     0  ...    1.94  3.00  3.50  2.10   NaN   NaN   NaN   NaN   NaN
#
#      LBCA
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 318   NaN
# 319   NaN
# 320   NaN
# 321   NaN
# 322   NaN
#
# [6658 rows x 163 columns]

# %% [markdown]
# ### Organize all the data in a dictionary

# %%
# create a dictionary with original name of league as key

dict_leagues = {'English Premier League':'E0','English Championship':'E1','English League 1':'E2','English League 2':'E3', 'English Conference (National League)':'EC'}

dict_leagues
# Out:
# {'English Premier League': 'E0',
#  'English Championship': 'E1',
#  'English League 1': 'E2',
#  'English League 2': 'E3',
#  'English Conference (National League)': 'EC'}

# %%
dict_leagues['English Premier League']
# Out:
# 'E0'

# %%
dict_historical_data = {}

for league in dict_leagues:
    frames = []
    for season in range(23,26):
        df=pd.read_csv(root + str(season) + str(season+1) + "/" + dict_leagues[league] + ".csv")
        df.insert(1,"season",season)
        frames.append(df)
    df_concat = pd.concat(frames)
    dict_historical_data[league] = df_concat

# %%
type(dict_historical_data)
# Out:
# dict

# %%
len(dict_historical_data)
# Out:
# 5

# %%
dict_historical_data['English Premier League']
# Out:
#     Div  season        Date   Time       HomeTeam       AwayTeam  FTHG  FTAG  \
# 0    E0      23  11/08/2023  20:00        Burnley       Man City     0     3
# 1    E0      23  12/08/2023  12:30        Arsenal  Nott'm Forest     2     1
# 2    E0      23  12/08/2023  15:00    Bournemouth       West Ham     1     1
# 3    E0      23  12/08/2023  15:00       Brighton          Luton     4     1
# 4    E0      23  12/08/2023  15:00        Everton         Fulham     0     1
# ..   ..     ...         ...    ...            ...            ...   ...   ...
# 215  E0      25  17/01/2026  15:00      Tottenham       West Ham     1     2
# 216  E0      25  17/01/2026  17:30  Nott'm Forest        Arsenal     0     0
# 217  E0      25  18/01/2026  14:00         Wolves      Newcastle     0     0
# 218  E0      25  18/01/2026  16:30    Aston Villa        Everton     0     1
# 219  E0      25  19/01/2026  20:00       Brighton    Bournemouth     1     1
#
#     FTR  HTHG  ...  BMGMCA  BVCH BVCD  BVCA  CLCH  CLCD  CLCA  LBCH  LBCD  \
# 0     A     0  ...     NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     H     2  ...     NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     D     0  ...     NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     H     1  ...     NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     A     0  ...     NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..   ..   ...  ...     ...   ...  ...   ...   ...   ...   ...   ...   ...
# 215   A     0  ...    4.40  1.83  3.8   4.1  1.85  3.75  4.00  1.83  3.75
# 216   D     0  ...    1.61  5.75  3.9   1.6  5.50  3.90  1.61  5.25  3.90
# 217   D     0  ...    1.74  4.60  4.1   1.7  4.33  3.90  1.75  4.33  3.90
# 218   A     0  ...    6.10  1.55  3.9   6.5  1.60  4.00  5.50  1.60  4.00
# 219   D     0  ...    3.60  1.95  3.8   3.6  1.91  3.90  3.50  1.91  3.90
#
#      LBCA
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 215  4.00
# 216  1.61
# 217  1.75
# 218  5.25
# 219  3.50
#
# [980 rows x 163 columns]

# %% [markdown]
# ## Analysis and visualizations

# %%
# Raw Dataset

DF_Concat
# Out:
#     Div  Season        Date   Time      HomeTeam       AwayTeam  FTHG  FTAG  \
# 0    E0      23  11/08/2023  20:00       Burnley       Man City     0     3
# 1    E0      23  12/08/2023  12:30       Arsenal  Nott'm Forest     2     1
# 2    E0      23  12/08/2023  15:00   Bournemouth       West Ham     1     1
# 3    E0      23  12/08/2023  15:00      Brighton          Luton     4     1
# 4    E0      23  12/08/2023  15:00       Everton         Fulham     0     1
# ..   ..     ...         ...    ...           ...            ...   ...   ...
# 318  EC      25  20/01/2026  19:45         Truro  Brackley Town     3     3
# 319  EC      25  21/01/2026  19:45      Carlisle           York     0     3
# 320  EC      25  21/01/2026  19:45  Forest Green     Altrincham     1     1
# 321  EC      25  21/01/2026  19:45       Halifax      Morecambe     1     0
# 322  EC      25  21/01/2026  19:45      Solihull       Rochdale     0     1
#
#     FTR  HTHG  ...  BMGMCA  BVCH  BVCD  BVCA  CLCH  CLCD  CLCA  LBCH  LBCD  \
# 0     A     0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     H     2  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     D     0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     H     1  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     A     0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..   ..   ...  ...     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 318   D     0  ...    2.75  2.38  3.10  2.88   NaN   NaN   NaN   NaN   NaN
# 319   A     0  ...    2.20  2.75  3.60  2.20   NaN   NaN   NaN   NaN   NaN
# 320   D     0  ...    7.50  1.25  5.25  9.50   NaN   NaN   NaN   NaN   NaN
# 321   H     1  ...    3.45  1.80  3.80  3.70   NaN   NaN   NaN   NaN   NaN
# 322   A     0  ...    1.94  3.00  3.50  2.10   NaN   NaN   NaN   NaN   NaN
#
#      LBCA
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 318   NaN
# 319   NaN
# 320   NaN
# 321   NaN
# 322   NaN
#
# [6658 rows x 163 columns]

# %% [markdown]
# ### Feature Understanding (Key Columns)
#
# FTHG - Full Time Home Goals
#
# FTAG - Full Time Away Goals
#
# HTR	 - Half Time Result (H - Home team , D - Draw , Away team)
#
# FTR	 - Full Time / Match Result (H - Home team , D - Draw , Away team)
#
# HTHG - Half Time Home Goals
#
# HTAG - Half Time Away Goals
#
# HS/AS -	Shots (Home/Away)
#
# HST/AST	- Shots on Target (Home/Away)
#
# HC/AC - Corners (Home/Away)
#
# HF/AF - Fouls (Home/Away)
#
# HY/AY -	Yellow Cards (Home/Away)
#
# HR/AR -	Red Cards (Home/Away)

# %%
# selecting only the key columns

df = DF_Concat[['Div', 'Season', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG',
       'FTR', 'HTHG', 'HTAG', 'HTR', 'HS', 'AS', 'HST', 'AST', 'HF',
       'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']]
df
# Out:
#     Div  Season        Date   Time      HomeTeam       AwayTeam  FTHG  FTAG  \
# 0    E0      23  11/08/2023  20:00       Burnley       Man City     0     3
# 1    E0      23  12/08/2023  12:30       Arsenal  Nott'm Forest     2     1
# 2    E0      23  12/08/2023  15:00   Bournemouth       West Ham     1     1
# 3    E0      23  12/08/2023  15:00      Brighton          Luton     4     1
# 4    E0      23  12/08/2023  15:00       Everton         Fulham     0     1
# ..   ..     ...         ...    ...           ...            ...   ...   ...
# 318  EC      25  20/01/2026  19:45         Truro  Brackley Town     3     3
# 319  EC      25  21/01/2026  19:45      Carlisle           York     0     3
# 320  EC      25  21/01/2026  19:45  Forest Green     Altrincham     1     1
# 321  EC      25  21/01/2026  19:45       Halifax      Morecambe     1     0
# 322  EC      25  21/01/2026  19:45      Solihull       Rochdale     0     1
#
#     FTR  HTHG  ...   HST  AST    HF    AF    HC   AC  HY  AY  HR  AR
# 0     A     0  ...   1.0  8.0  11.0   8.0   6.0  5.0   0   0   1   0
# 1     H     2  ...   7.0  2.0  12.0  12.0   8.0  3.0   2   2   0   0
# 2     D     0  ...   5.0  3.0   9.0  14.0  10.0  4.0   1   4   0   0
# 3     H     1  ...  12.0  3.0  11.0  12.0   6.0  7.0   2   2   0   0
# 4     A     0  ...   9.0  2.0  12.0   6.0  10.0  4.0   0   2   0   0
# ..   ..   ...  ...   ...  ...   ...   ...   ...  ...  ..  ..  ..  ..
# 318   D     0  ...   NaN  NaN   NaN   NaN   NaN  NaN   2   2   0   0
# 319   A     0  ...   NaN  NaN   NaN   NaN   NaN  NaN   0   0   0   0
# 320   D     0  ...   NaN  NaN   NaN   NaN   NaN  NaN   2   2   0   0
# 321   H     1  ...   NaN  NaN   NaN   NaN   NaN  NaN   2   4   0   0
# 322   A     0  ...   NaN  NaN   NaN   NaN   NaN  NaN   0   0   0   0
#
# [6658 rows x 24 columns]

# %%
# Dataset Overview

print(df.describe())

print("#############")

print(df.info())
# Out:
#             Season         FTHG         FTAG         HTHG         HTAG  \
# count  6658.000000  6658.000000  6658.000000  6658.000000  6658.000000
# mean     23.833884     1.498047     1.222589     0.671823     0.541604
# std       0.764060     1.256288     1.106750     0.824181     0.747433
# min      23.000000     0.000000     0.000000     0.000000     0.000000
# 25%      23.000000     1.000000     0.000000     0.000000     0.000000
# 50%      24.000000     1.000000     1.000000     0.000000     0.000000
# 75%      24.000000     2.000000     2.000000     1.000000     1.000000
# max      25.000000     9.000000     8.000000     5.000000     5.000000
#
#                 HS           AS          HST          AST           HF  \
# count  5231.000000  5231.000000  5231.000000  5231.000000  5231.000000
# mean     13.436437    11.098452     4.512904     3.740776    10.886829
# std       5.171303     4.672942     2.403188     2.195968     3.458218
# min       0.000000     0.000000     0.000000     0.000000     1.000000
# 25%      10.000000     8.000000     3.000000     2.000000     8.000000
# 50%      13.000000    11.000000     4.000000     3.000000    11.000000
# 75%      16.000000    14.000000     6.000000     5.000000    13.000000
# max      39.000000    37.000000    16.000000    15.000000    25.000000
#
#                AF           HC           AC           HY           AY  \
# count  5231.00000  5231.000000  5231.000000  6658.000000  6658.000000
# mean     11.54999     5.558019     4.612311     1.793031     2.063533
# std       3.58840     2.970156     2.642778     1.301066     1.351431
# min       1.00000     0.000000     0.000000     0.000000     0.000000
# 25%       9.00000     3.000000     3.000000     1.000000     1.000000
# 50%      11.00000     5.000000     4.000000     2.000000     2.000000
# 75%      14.00000     7.000000     6.000000     3.000000     3.000000
# max      25.00000    19.000000    19.000000     8.000000     9.000000
#
#                 HR           AR
# count  6658.000000  6658.000000
# mean      0.061280     0.081256
# std       0.249078     0.285086
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     0.000000
# max       2.000000     2.000000
# #############
# <class 'pandas.core.frame.DataFrame'>
# Index: 6658 entries, 0 to 322
# Data columns (total 24 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Div       6658 non-null   object
#  1   Season    6658 non-null   int64
#  2   Date      6658 non-null   object
#  3   Time      6658 non-null   object
#  4   HomeTeam  6658 non-null   object
#  5   AwayTeam  6658 non-null   object
#  6   FTHG      6658 non-null   int64
#  7   FTAG      6658 non-null   int64
#  8   FTR       6658 non-null   object
#  9   HTHG      6658 non-null   int64
#  10  HTAG      6658 non-null   int64
#  11  HTR       6658 non-null   object
#  12  HS        5231 non-null   float64
#  13  AS        5231 non-null   float64
#  14  HST       5231 non-null   float64
#  15  AST       5231 non-null   float64
#  16  HF        5231 non-null   float64
#  17  AF        5231 non-null   float64
#  18  HC        5231 non-null   float64
#  19  AC        5231 non-null   float64
#  20  HY        6658 non-null   int64
#  21  AY        6658 non-null   int64
#  22  HR        6658 non-null   int64
#  23  AR        6658 non-null   int64
# dtypes: float64(8), int64(9), object(7)
# memory usage: 1.3+ MB
# None

# %%
# Missing Value Analysis - All columns have love missing values

df.isna().mean().sort_values(ascending=False)
# Out:
# HS          0.214329
# AC          0.214329
# HC          0.214329
# AF          0.214329
# HF          0.214329
# AST         0.214329
# HST         0.214329
# AS          0.214329
# Season      0.000000
# HR          0.000000
# AY          0.000000
# HY          0.000000
# Div         0.000000
# HTR         0.000000
# HTAG        0.000000
# HTHG        0.000000
# FTR         0.000000
# FTAG        0.000000
# FTHG        0.000000
# AwayTeam    0.000000
# HomeTeam    0.000000
# Time        0.000000
# Date        0.000000
# AR          0.000000
# dtype: float64

# %%
# Convert Date column

df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
# Goal Distribution (Home vs Away)

plt.hist(df['FTHG'], bins=10)
plt.title("Home Goals Distribution")
plt.show()

plt.hist(df['FTAG'], bins=10)
plt.title("Away Goals Distribution")
plt.show()

# %%
# Home vs Away Advantage (All seasons together)

df['FTR'].value_counts(normalize=True) * 100
# Out:
# FTR
# H    43.466506
# A    31.195554
# D    25.337939
# Name: proportion, dtype: float64

# %%
# Home vs Away Advantage (by each seasons)

print(df.groupby("Season")['FTR'].value_counts(normalize=True) * 100)

sns.countplot(x='FTR', data=df, hue = 'Season')
plt.title("Match Result Distribution")
plt.show()
# Out:
# Season  FTR
# 23      H      43.894900
#         A      32.225657
#         D      23.879444
# 24      H      42.928903
#         A      30.177743
#         D      26.893354
# 25      H      43.657220
#         A      31.174089
#         D      25.168691
# Name: proportion, dtype: float64

# %%
# Average Goals per Match

df['TotalGoals'] = df['FTHG'] + df['FTAG']
print(df['TotalGoals'].mean())

sns.histplot(df['TotalGoals'], bins=10, kde=True)
plt.title("Total Goals per Match")
plt.show()
# Out:
# 2.720636827876239

# %%
# Top 10 goal scoring teams at Home - Average Goals Scored

home_goals = df.groupby('HomeTeam')['FTHG'].mean().sort_values(ascending=False)
home_goals.head(10)
# Out:
# HomeTeam
# Man City        2.469388
# Newcastle       2.265306
# Arsenal         2.224490
# Leeds           2.192982
# Chesterfield    2.186441
# Liverpool       2.183673
# York            2.183333
# Barnet          2.172414
# Wrexham         2.114754
# Aston Villa     2.040816
# Name: FTHG, dtype: float64

# %%
# Top 10 goal scoring teams on away games - Average Goals Scored

away_goals = df.groupby('AwayTeam')['FTAG'].mean().sort_values(ascending=False)
away_goals.head(10)
# Out:
# AwayTeam
# Liverpool      2.000000
# Man City       1.877551
# Arsenal        1.857143
# Scunthorpe     1.785714
# Tottenham      1.693878
# Gateshead      1.666667
# Bournemouth    1.653061
# Chelsea        1.653061
# Stockport      1.637931
# Barnsley       1.631579
# Name: FTAG, dtype: float64

# %%
# Top 10 goal conceding teams at Home games - Average Goals Conceded

home_conceded = df.groupby('HomeTeam')['FTAG'].mean().sort_values(ascending=False)
home_conceded.head(10)
# Out:
# HomeTeam
# West Ham            1.775510
# Dorking             1.739130
# Wolves              1.734694
# Oxford City         1.695652
# Fylde               1.673913
# Brentford           1.612245
# Sheffield United    1.611111
# Aldershot           1.610169
# Eastleigh           1.603448
# Southampton         1.589286
# Name: FTAG, dtype: float64

# %%
# Top 10 goal conceding teams at Away games - Average Goals Conceded

away_conceded = df.groupby('AwayTeam')['FTHG'].mean().sort_values(ascending=False)
away_conceded.head(10)
# Out:
# AwayTeam
# Truro          2.461538
# Oxford City    2.391304
# Ebbsfleet      2.282609
# Luton          2.111111
# Aldershot      2.100000
# Tamworth       2.027027
# Bournemouth    2.020408
# Morecambe      1.966667
# Fylde          1.956522
# Dorking        1.956522
# Name: FTHG, dtype: float64

# %%
# Discipline Analysis (Cards)

df[['HY', 'AY', 'HR', 'AR']].describe()
# Out:
#                 HY           AY           HR           AR
# count  6658.000000  6658.000000  6658.000000  6658.000000
# mean      1.793031     2.063533     0.061280     0.081256
# std       1.301066     1.351431     0.249078     0.285086
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     1.000000     0.000000     0.000000
# 50%       2.000000     2.000000     0.000000     0.000000
# 75%       3.000000     3.000000     0.000000     0.000000
# max       8.000000     9.000000     2.000000     2.000000

# %%
# Yellow Cards Distribution - Home Players vs Away Players

print(df['HY'].value_counts())
print(df['AY'].value_counts())

sns.boxplot(data=df[['HY','AY']])
plt.title("Yellow Cards Distribution")
plt.show()
# Out:
# HY
# 1    1977
# 2    1852
# 3    1074
# 0    1063
# 4     488
# 5     151
# 6      44
# 7       8
# 8       1
# Name: count, dtype: int64
# AY
# 2    1897
# 1    1703
# 3    1337
# 0     764
# 4     652
# 5     227
# 6      62
# 7      13
# 8       2
# 9       1
# Name: count, dtype: int64

# %%
# Red Cards Distribution - Home Players vs Away Players

print(df['HR'].value_counts())
print(df['AR'].value_counts())

sns.violinplot(data=df[['HR','AR']])
plt.title("Red Cards Distribution")
plt.show()
# Out:
# HR
# 0    6265
# 1     378
# 2      15
# Name: count, dtype: int64
# AR
# 0    6139
# 1     497
# 2      22
# Name: count, dtype: int64

# %%
# correlation b/w shots on target and goals scored

df['Total_Shots_On_Target'] = df['HST'] + df['AST']
df['Total_Goals'] = df['FTHG'] + df['FTAG']

correlation = df['Total_Shots_On_Target'].corr(df['Total_Goals'])
print(f"Correlation between shots on target and goals: {correlation:.3f}")

plt.figure(figsize=(8, 6))
plt.scatter(df['Total_Shots_On_Target'], df['Total_Goals'])
plt.xlabel("Total Shots on Target")
plt.ylabel("Total Goals Scored")
plt.title("Relationship Between Shots on Target and Goals")
plt.show()
# Out:
# Correlation between shots on target and goals: 0.566

# %%
# Half-Time Lead vs Full-Time Result

df['HT_Leader'] = df.apply(
    lambda x: 'Home Leading' if x['HTHG'] > x['HTAG']
    else 'Away Leading' if x['HTHG'] < x['HTAG']
    else 'Level',
    axis=1
)

print(pd.crosstab(df['HT_Leader'], df['FTR'], normalize='index') * 100)

summary = pd.crosstab(df['HT_Leader'], df['FTR'], normalize='index') * 100
summary.plot(kind='bar', stacked=True, figsize=(8,6))
plt.xlabel("Half-Time Match State")
plt.ylabel("Percentage of Matches")
plt.title("Final Match Outcome Based on Half-Time Lead")
plt.legend(title="Full-Time Result")
plt.show()
# Out:
# FTR                   A          D          H
# HT_Leader
# Away Leading  67.815421  20.385514  11.799065
# Home Leading   6.663725  17.166814  76.169462
# Level         28.544776  35.410448  36.044776

# %%
# Fouls committed - Home vs Away

sns.boxplot(data=df[['HF', 'AF']])
plt.title("Fouls: Home vs Away")
plt.show()

# %% [markdown]
# ### Correlation Analysis

# %%
numeric_cols = df.select_dtypes(include=np.number)
corr = numeric_cols.corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr, cmap='coolwarm', center=0)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Conclusions:

# %% [markdown]
#  - Home teams win ~43–45% of matches → clear home advantage
#
#  - Average goals per match ≈ 2.7
#
#  - Yellow cards are much more frequent than red cards
#
#  - Away team players gets more yellow and red cards than home team players
#
#  - Find out top 10 goal scoring/conceding team in both Home and Away matches
#
#  - Shots on target strongly correlate with goals scored
#
#  - Teams leading (by goals count) at half-time are far more likely to win the match
#
#  - Away teams commit slightly more fouls than home teams
